# %% [markdown]
# # World Population by Country
#
# #### Exploratory Data Analysis with Python
#
# Dataset source: https://www.kaggle.com/code/arnavsmayan/world-population-analysis-notebook/input
#
# File: countries-table.csv (29.5 kB)
#
# Dataset provided by Arnav Smayan
#
# Retrieved: 6-August-2023

# %%
# Import required libraries/modules

import pandas as pd
import os
import warnings as wn
wn.filterwarnings('ignore')

# %%
# Change working directory to Downloads

os.chdir(os.getcwd() + '\Downloads')

# %%
# select the relevant columns

df = pd.read_csv('countries-table.csv') \
    [['country', 'landAreaKm', 'growthRate', 'netChange', 'pop1980', 'pop2000','pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050']]

df
# Out:
#               country  landAreaKm  growthRate  netChange    pop1980  \
# 0               India  2973190.00      0.0081     0.4184  696828385
# 1               China  9424702.90     -0.0002    -0.0113  982372466
# 2       United States  9147420.00      0.0050     0.0581  223140018
# 3           Indonesia  1877519.00      0.0074     0.0727  148177096
# 4            Pakistan   770880.00      0.0198     0.1495   80624057
# ..                ...         ...         ...        ...        ...
# 229        Montserrat      102.00     -0.0009        NaN      11452
# 230  Falkland Islands    12173.00      0.0029        NaN       2240
# 231              Niue      261.00      0.0005     0.0000       3637
# 232           Tokelau       10.00      0.0118        NaN       1647
# 233      Vatican City        0.44      0.0157        NaN        733
#
#         pop2000     pop2010     pop2022     pop2023     pop2030     pop2050
# ...

# %%
# Check the number of rows and columns (rows, columns)

df.shape
# Out:
# (234, 11)

# %%
# List out the columns in the dataset

df.columns
# Out:
# Index(['country', 'landAreaKm', 'growthRate', 'netChange', 'pop1980',
#        'pop2000', 'pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050'],
#       dtype='object')

# %%
# check the data types of the columns

df.dtypes
# Out:
# country        object
# landAreaKm    float64
# growthRate    float64
# netChange     float64
# pop1980         int64
# pop2000         int64
# pop2010         int64
# pop2022         int64
# pop2023         int64
# pop2030         int64
# pop2050         int64
# dtype: object

# %%
# Display the netChange and growthRate per country

df.groupby('country', as_index = False)[('netChange', 'growthRate')].sum()
# Out:
#                country  netChange  growthRate
# 0          Afghanistan     0.0357      0.0270
# 1              Albania    -0.0003     -0.0035
# 2              Algeria     0.0218      0.0157
# 3       American Samoa     0.0000     -0.0081
# 4              Andorra     0.0000      0.0033
# ..                 ...        ...         ...
# 229  Wallis and Futuna     0.0000     -0.0060
# 230     Western Sahara     0.0004      0.0196
# 231              Yemen     0.0240      0.0224
# 232             Zambia     0.0178      0.0276
# 233           Zimbabwe     0.0112      0.0211
#
# [234 rows x 3 columns]

# %%
# Display the landAreaKm per country

df.groupby('country', as_index = False)['landAreaKm'].mean()
# Out:
#                country  landAreaKm
# 0          Afghanistan    652230.0
# 1              Albania     27400.0
# 2              Algeria   2381741.0
# 3       American Samoa       200.0
# 4              Andorra       470.0
# ..                 ...         ...
# 229  Wallis and Futuna       274.0
# 230     Western Sahara    266000.0
# 231              Yemen    527970.0
# 232             Zambia    743390.0
# 233           Zimbabwe    386850.0
#
# [234 rows x 2 columns]

# %%
# Plot the landAreaKm per country as a pie chart

df.groupby('country')['landAreaKm'].mean().plot(kind = 'pie', figsize = (30,10))
# Out:
# <AxesSubplot:ylabel='landAreaKm'>

# %%
# Explore simple summary stats

df[['landAreaKm', 'growthRate']].describe(include='all')
# Out:
#          landAreaKm  growthRate
# count  2.340000e+02  234.000000
# mean   5.571123e+05    0.009737
# std    1.689972e+06    0.012350
# min    4.400000e-01   -0.074500
# 25%    2.625875e+03    0.002325
# 50%    7.568925e+04    0.008200
# 75%    4.047876e+05    0.016850
# max    1.637687e+07    0.049800

# %%
# look at the dataframe once again, this time, the tiny countries

df.sort_values('landAreaKm', ascending=False).tail(20)
# Out:
#                     country  landAreaKm  growthRate  netChange  pop1980  \
# 197                   Aruba      180.00     -0.0016     0.0000    62267
# 214        Marshall Islands      180.00      0.0103     0.0000    31988
# 215           Liechtenstein      160.00      0.0065     0.0000    25003
# 220  British Virgin Islands      150.00      0.0074     0.0000    11109
# 194                  Jersey      120.00      0.0092     0.0000    75124
# 229              Montserrat      102.00     -0.0009        NaN    11452
# 223                Anguilla       91.00      0.0026     0.0000     6560
# 206                Guernsey       63.00      0.0038     0.0000    52860
# 217              San Marino       60.00     -0.0005        NaN    21346
# 205                 Bermuda       54.00     -0.0018     0.0000    53565
# 219            Saint Martin       50.00      0.0090     0.0000     7776
# 212            Sint Maarten       34.00      0.0011     0.0000    12243
# ...

# %%
# We chose to filter off countries that are less than 50,000 in land area size

data = df[df['landAreaKm']  > 50000]

data
# Out:
#             country  landAreaKm  growthRate  netChange    pop1980     pop2000  \
# 0             India   2973190.0      0.0081     0.4184  696828385  1059633675
# 1             China   9424702.9     -0.0002    -0.0113  982372466  1264099069
# 2     United States   9147420.0      0.0050     0.0581  223140018   282398554
# 3         Indonesia   1877519.0      0.0074     0.0727  148177096   214072421
# 4          Pakistan    770880.0      0.0198     0.1495   80624057   154369924
# ..              ...         ...         ...        ...        ...         ...
# 169        Suriname    156000.0      0.0084     0.0002     375112      478998
# 171  Western Sahara    266000.0      0.0196     0.0004     116775      270375
# 178         Iceland    100830.0      0.0065     0.0001     228263      281462
# 182   French Guiana     83534.0      0.0249     0.0002      66825      164351
# 207       Greenland    410450.0      0.0031     0.0000      50106       56184
#
# ...

# %%
# Explore simple summary stats once more

data[['landAreaKm', 'growthRate']].describe(include='all')
# Out:
#          landAreaKm  growthRate
# count  1.290000e+02  129.000000
# mean   1.002629e+06    0.011984
# std    2.180110e+06    0.013830
# min    5.106000e+04   -0.074500
# 25%    1.289000e+05    0.005000
# 50%    3.415000e+05    0.011400
# 75%    8.232900e+05    0.021500
# max    1.637687e+07    0.049800

# %%
# Examine the upper quartile of land area

data['landAreaKm'].quantile(0.75)
# Out:
# 823290.0

# %%
# Examine the upper quartile of growth rate

data['growthRate'].quantile(0.75)
# Out:
# 0.0215

# %%
# What are the top 5 largest countries whose growth rate are in the top 25%?

data[data['growthRate'] >= data['growthRate'].quantile(0.75)].sort_values('landAreaKm', ascending=False).head()
# Out:
#      country  landAreaKm  growthRate  netChange   pop1980   pop2000   pop2010  \
# 14  DR Congo   2267050.0      0.0329     0.1050  26708686  48616317  66391257
# 30     Sudan   1868000.0      0.0263     0.0394  16673586  26298773  33739933
# 53     Niger   1266700.0      0.0380     0.0321   6173177  11622665  16647543
# 66      Chad   1259200.0      0.0313     0.0178   4408230   8259137  11894727
# 41    Angola   1246700.0      0.0308     0.0352   8330047  16394062  23364185
#
#      pop2022    pop2023    pop2030    pop2050
# 14  99010212  102262808  127582053  217494003
# 30  46874204   48109006   56997099   84494269
# 53  26207977   27202843   35217942   67043296
# 66  17723315   18278568   22460393   36452035
# 41  35588987   36684202   44911664   72328068

# %%
# What are the top 5 most growing countries whose size are in the top 25%?

data[data['landAreaKm'] >= data['landAreaKm'].quantile(0.75)].sort_values('growthRate', ascending=False).head()
# Out:
#      country  landAreaKm  growthRate  netChange   pop1980   pop2000   pop2010  \
# 53     Niger   1266700.0      0.0380     0.0321   6173177  11622665  16647543
# 14  DR Congo   2267050.0      0.0329     0.1050  26708686  48616317  66391257
# 66      Chad   1259200.0      0.0313     0.0178   4408230   8259137  11894727
# 57      Mali   1220190.0      0.0310     0.0225   7372581  11239101  15529181
# 41    Angola   1246700.0      0.0308     0.0352   8330047  16394062  23364185
#
#      pop2022    pop2023    pop2030    pop2050
# 53  26207977   27202843   35217942   67043296
# 14  99010212  102262808  127582053  217494003
# 66  17723315   18278568   22460393   36452035
# 57  22593590   23293698   28712294   47439802
# 41  35588987   36684202   44911664   72328068

# %%
# Examine the countries with highest growth rates and land areas

data.sort_values(['growthRate', 'landAreaKm'], ascending=False).head()
# Out:
#      country  landAreaKm  growthRate  netChange   pop1980   pop2000   pop2010  \
# 59     Syria    183630.0      0.0498     0.0359   8898954  16307654  22337563
# 53     Niger   1266700.0      0.0380     0.0321   6173177  11622665  16647543
# 14  DR Congo   2267050.0      0.0329     0.1050  26708686  48616317  66391257
# 66      Chad   1259200.0      0.0313     0.0178   4408230   8259137  11894727
# 57      Mali   1220190.0      0.0310     0.0225   7372581  11239101  15529181
#
#      pop2022    pop2023    pop2030    pop2050
# 59  22125249   23227014   29824735   38306374
# 53  26207977   27202843   35217942   67043296
# 14  99010212  102262808  127582053  217494003
# 66  17723315   18278568   22460393   36452035
# 57  22593590   23293698   28712294   47439802

# %%
# Considering the top 5 most growing countries whose sizes are in the top 25%

top_growth_land = data[data['landAreaKm'] >= data['landAreaKm'].quantile(0.75)] \
                .sort_values('growthRate', ascending=False).head()

top_growth_land
# Out:
#      country  landAreaKm  growthRate  netChange   pop1980   pop2000   pop2010  \
# 53     Niger   1266700.0      0.0380     0.0321   6173177  11622665  16647543
# 14  DR Congo   2267050.0      0.0329     0.1050  26708686  48616317  66391257
# 66      Chad   1259200.0      0.0313     0.0178   4408230   8259137  11894727
# 57      Mali   1220190.0      0.0310     0.0225   7372581  11239101  15529181
# 41    Angola   1246700.0      0.0308     0.0352   8330047  16394062  23364185
#
#      pop2022    pop2023    pop2030    pop2050
# 53  26207977   27202843   35217942   67043296
# 14  99010212  102262808  127582053  217494003
# 66  17723315   18278568   22460393   36452035
# 57  22593590   23293698   28712294   47439802
# 41  35588987   36684202   44911664   72328068

# %%
# let's visualize a line plot comparison of population trends per year per country
## first we have to select the relevant columns for this plot

top_growth_land[['country', 'pop1980', 'pop2000','pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050']]
# Out:
#      country   pop1980   pop2000   pop2010   pop2022    pop2023    pop2030  \
# 53     Niger   6173177  11622665  16647543  26207977   27202843   35217942
# 14  DR Congo  26708686  48616317  66391257  99010212  102262808  127582053
# 66      Chad   4408230   8259137  11894727  17723315   18278568   22460393
# 57      Mali   7372581  11239101  15529181  22593590   23293698   28712294
# 41    Angola   8330047  16394062  23364185  35588987   36684202   44911664
#
#       pop2050
# 53   67043296
# 14  217494003
# 66   36452035
# 57   47439802
# 41   72328068

# %%
# Then we plot comparison of population trends per year per country as line plot

top_growth_land[['country', 'pop1980', 'pop2000','pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050']] \
    .plot.line(x='country', figsize=(15, 8))
# Out:
# <AxesSubplot:xlabel='country'>

# %%
# The above plot is not clear
## We need to make the country become legend, so that the population becomes values
### to do this, we need to transpose the dataframe before passing it to the plot.line() method

# %%
# However to pass this dataframe to the plot.line() method we need to transpose it, 
## but we must promote the first column to become an index before we transpose
### this is how it appears when we set index to country:

top_growth_land[['country', 'pop1980', 'pop2000','pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050']].set_index('country')
# Out:
#            pop1980   pop2000   pop2010   pop2022    pop2023    pop2030  \
# country
# Niger      6173177  11622665  16647543  26207977   27202843   35217942
# DR Congo  26708686  48616317  66391257  99010212  102262808  127582053
# Chad       4408230   8259137  11894727  17723315   18278568   22460393
# Mali       7372581  11239101  15529181  22593590   23293698   28712294
# Angola     8330047  16394062  23364185  35588987   36684202   44911664
#
#             pop2050
# country
# Niger      67043296
# DR Congo  217494003
# Chad       36452035
# Mali       47439802
# Angola     72328068

# %%
# This is the transposed dataframe

top_growth_land_trans = top_growth_land[['country', 'pop1980', 'pop2000','pop2010', 'pop2022', \
                                         'pop2023', 'pop2030', 'pop2050']] \
                                        .set_index('country').transpose()

top_growth_land_trans
# Out:
# country     Niger   DR Congo      Chad      Mali    Angola
# pop1980   6173177   26708686   4408230   7372581   8330047
# pop2000  11622665   48616317   8259137  11239101  16394062
# pop2010  16647543   66391257  11894727  15529181  23364185
# pop2022  26207977   99010212  17723315  22593590  35588987
# pop2023  27202843  102262808  18278568  23293698  36684202
# pop2030  35217942  127582053  22460393  28712294  44911664
# pop2050  67043296  217494003  36452035  47439802  72328068

# %%
# Before we plot, we can just add a column for the average population per year for comparison sake

top_growth_land_trans['AVG_POP'] = (top_growth_land_trans['Niger'] \
                                + top_growth_land_trans['DR Congo'] \
                                + top_growth_land_trans['Chad'] \
                                + top_growth_land_trans['Mali'] \
                                + top_growth_land_trans['Angola']) / 5

top_growth_land_trans
# Out:
# country     Niger   DR Congo      Chad      Mali    Angola     AVG_POP
# pop1980   6173177   26708686   4408230   7372581   8330047  10598544.2
# pop2000  11622665   48616317   8259137  11239101  16394062  19226256.4
# pop2010  16647543   66391257  11894727  15529181  23364185  26765378.6
# pop2022  26207977   99010212  17723315  22593590  35588987  40224816.2
# pop2023  27202843  102262808  18278568  23293698  36684202  41544423.8
# pop2030  35217942  127582053  22460393  28712294  44911664  51776869.2
# pop2050  67043296  217494003  36452035  47439802  72328068  88151440.8

# %%
# Visualizing the top 5 most growing countries whose sizes are in the top 25%

top_growth_land_trans.plot(kind = 'line', figsize=(15, 8), title='population of countries by year', \
                color={'AVG_POP':'black', 'Niger':'red', 'DR Congo':'yellow', 'Chad':'green', 'Mali':'blue', 'Angola':'orange'})
# Out:
# <AxesSubplot:title={'center':'population of countries by year'}>

# %%
# Visualizing the Population by land Area in Km sq of the top 5 most growing countries whose size are in the top 25%

top_growth_land.plot(kind = 'barh', x='country', y='landAreaKm', title='Population by land Area in Km sq', \
                     legend=False, figsize=(15, 6), color=['green', 'orange', 'red', 'blue', 'yellow'])
# Out:
# <AxesSubplot:title={'center':'Population by land Area in Km sq'}, ylabel='country'>

# %%
# Visualizing the Growth rate per country of the top 5 most growing countries whose size are in the top 25%

top_growth_land.plot(kind = 'barh', x='country', y='growthRate', title='Growth rate per country', \
                     legend=False, figsize=(15, 6))
# Out:
# <AxesSubplot:title={'center':'Growth rate per country'}, ylabel='country'>

# %%
# Considering the top 5 largest countries whose growth rate are in the top 25%

top_growth_land = data[data['growthRate'] >= data['growthRate'].quantile(0.75)].sort_values('landAreaKm', ascending=False).head()

top_growth_land
# Out:
#      country  landAreaKm  growthRate  netChange   pop1980   pop2000   pop2010  \
# 14  DR Congo   2267050.0      0.0329     0.1050  26708686  48616317  66391257
# 30     Sudan   1868000.0      0.0263     0.0394  16673586  26298773  33739933
# 53     Niger   1266700.0      0.0380     0.0321   6173177  11622665  16647543
# 66      Chad   1259200.0      0.0313     0.0178   4408230   8259137  11894727
# 41    Angola   1246700.0      0.0308     0.0352   8330047  16394062  23364185
#
#      pop2022    pop2023    pop2030    pop2050
# 14  99010212  102262808  127582053  217494003
# 30  46874204   48109006   56997099   84494269
# 53  26207977   27202843   35217942   67043296
# 66  17723315   18278568   22460393   36452035
# 41  35588987   36684202   44911664   72328068

# %%
# Select the country column as well as the yearly population columns

top_growth_land[['country', 'pop1980', 'pop2000','pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050']]
# Out:
#      country   pop1980   pop2000   pop2010   pop2022    pop2023    pop2030  \
# 14  DR Congo  26708686  48616317  66391257  99010212  102262808  127582053
# 30     Sudan  16673586  26298773  33739933  46874204   48109006   56997099
# 53     Niger   6173177  11622665  16647543  26207977   27202843   35217942
# 66      Chad   4408230   8259137  11894727  17723315   18278568   22460393
# 41    Angola   8330047  16394062  23364185  35588987   36684202   44911664
#
#       pop2050
# 14  217494003
# 30   84494269
# 53   67043296
# 66   36452035
# 41   72328068

# %%
# Let's set the country column as index

top_growth_land[['country', 'pop1980', 'pop2000','pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050']].set_index('country')
# Out:
#            pop1980   pop2000   pop2010   pop2022    pop2023    pop2030  \
# country
# DR Congo  26708686  48616317  66391257  99010212  102262808  127582053
# Sudan     16673586  26298773  33739933  46874204   48109006   56997099
# Niger      6173177  11622665  16647543  26207977   27202843   35217942
# Chad       4408230   8259137  11894727  17723315   18278568   22460393
# Angola     8330047  16394062  23364185  35588987   36684202   44911664
#
#             pop2050
# country
# DR Congo  217494003
# Sudan      84494269
# Niger      67043296
# Chad       36452035
# Angola     72328068

# %%
# Then let's transpose

top_growth_land_trans = top_growth_land[['country', 'pop1980', 'pop2000','pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050']] \
                    .set_index('country').transpose()

top_growth_land_trans
# Out:
# country   DR Congo     Sudan     Niger      Chad    Angola
# pop1980   26708686  16673586   6173177   4408230   8330047
# pop2000   48616317  26298773  11622665   8259137  16394062
# pop2010   66391257  33739933  16647543  11894727  23364185
# pop2022   99010212  46874204  26207977  17723315  35588987
# pop2023  102262808  48109006  27202843  18278568  36684202
# pop2030  127582053  56997099  35217942  22460393  44911664
# pop2050  217494003  84494269  67043296  36452035  72328068

# %%
# We then plot the yearly population trend per countries selected

top_growth_land_trans.plot(kind = 'line', figsize = (16,8), title = 'population per country', 
                    color = ['red','black','yellow','green','orange'])
# Out:
# <AxesSubplot:title={'center':'population per country'}>

# %% [markdown]
# ##### Thanks for going through this case study with me!
